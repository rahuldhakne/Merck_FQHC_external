# %% [markdown]
# # Patient Basic
# Create patient cohort of all patients who have at least 1 claim wtih a code in `ref_cohort` between the dates of interest.
#
# **Script**
# * [scripts/coh/coh_basic.ipynb](./scripts/coh/coh_basic.ipynb)
#
# **Parameters**
# * `in/coh/coh_basic.xlsx[param]`
# * `in/coh/coh_basic.xlsx[ref]`
#
# **Input**
# * None
#
# **Output**
# * `coh_basic_ref`
# * `coh_basic_raven_diagnosis`
# * `coh_basic_raven_pharmacy`
# * `coh_basic_raven_procedure`
# * `coh_pt`
# * `coh_claim`
#
# **Review**
# * [scripts/coh/coh_basic.html](./scripts/coh/coh_basic.html)

# %%
#Import libraries for this notebook
import pandas as pd  
from drg_connect import Snowflake
import numpy as np
import pickle
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

#Load connection variables to connect_dict
with open('../../out/conn/connect_dict.pickle', 'rb') as handle:
    connect_dict = pickle.load(handle)

#Create Eegine to connect to snowflake
snow = Snowflake(role=connect_dict['role'],
                 warehouse=connect_dict['warehouse'],
                 database=connect_dict['database'],
                 schema=connect_dict['schema'])

#Finish engine setup
engine = snow.engine
# %load_ext sql_magic
# %config SQL.conn_name = 'engine'  #Set the sql_magic connection engine
# %config SQL.output_result = True  #Enable output to std out
# %config SQL.notify_result = False #disable browser notifications

# %% [markdown]
# # Parameters
# Python dictionary of parameters for the cohort basic procedure
#
# **Input**
# * `in/coh/coh_basic.xlsx[param]`
#
# **Output**
# * Python variables named after parameters with the value

# %%
#Create system variables from excel into script and review values in dictionary
input_df = pd.read_excel('../../in/coh/coh_basic.xlsx', sheet_name='param', skiprows=4, dtype=str)
var_dict = dict(zip(input_df.parameter, input_df.value))
for key,val in var_dict.items(): exec(key + '=val')

#Check inputs
pd.DataFrame.from_dict(var_dict, orient='index')
# Out:
#                             0
# med_dx_start_dt    2015-01-01
# med_dx_end_dt      2018-12-31
# med_proc_start_dt  2017-01-01
# med_proc_end_dt    2017-12-31
# phar_rx_start_dt   2017-01-01
# phar_rx_end_dt     2017-12-31

# %% [markdown]
# # Reference
# Uploads reference table to snowflake used to identify the cohort
#
# **Input**
#   * `in/coh/coh_basic.xlsx[ref]`
#
# **Output**
# * `coh_basic_ref`

# %%
#Upload reference table from excel to snowflake and review snowflake output
df = pd.read_excel('../../in/coh/coh_basic.xlsx', sheet_name='ref', skiprows=4, dtype=str)

#Strip white space, make referrable columns uppercase, and remove non alphanumeric values from coce
df = df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
df[['data_asset','code_type','code']] =  \
   df[['data_asset','code_type','code']].apply(lambda x: x.str.upper() if x.dtype == "object" else x)
df.code= df.code.str.replace(r'\W+','').astype('str')

#Upload to snowflake
snow.drop_table("coh_basic_ref")
snow.upload_dataframe(df,"coh_basic_ref")
snow.select("SELECT * FROM coh_basic_ref")
# Out:
# DROP TABLE IF EXISTS ref_db.semi_custom.coh_basic_ref;
# Initiating login request with your identity provider. A browser window should have opened for you to complete the login. If you can't see it, check existing browser windows, or your OS settings. Press CTRL+C to abort and try again...
# Table ref_db.semi_custom.coh_basic_ref dropped! (╯°□°）╯︵ ┻━┻
# Upload into ref_db.semi_custom.coh_basic_ref successful! ┬──┬◡ﾉ(°-°ﾉ)
#    data_asset code_type         code  \
# 0     MEDICAL      ICD9        34700
# 1     MEDICAL      ICD9        34701
# 2     MEDICAL      ICD9         3471
# 3     MEDICAL      ICD9        34711
# 4     MEDICAL     ICD10         G474
# 5     MEDICAL     ICD10        G4741
# 6     MEDICAL     ICD10       G47411
# 7     MEDICAL     ICD10       G47419
# 8     MEDICAL     ICD10        G4742
# 9     MEDICAL     ICD10       G47421
# 10    MEDICAL     ICD10        G4729
# 11   PHARMACY       NDC  68727010001
# 12   PHARMACY       NDC  62161000820
# 13    MEDICAL       NDC  68727010001
# 14    MEDICAL       NDC  62161000820
# 15    MEDICAL       CPT        61885
# 16    MEDICAL       CPT        61886
# 17    MEDICAL       CPT        63685
# 18    MEDICAL       CPT        64568
# 19    MEDICAL       CPT        64569
# 20    MEDICAL       CPT        64999
# 21    MEDICAL     HCPCS        C1767
# 22    MEDICAL     HCPCS        C1820
# 23    MEDICAL     HCPCS        L8679
# 24    MEDICAL     HCPCS        L8686
# 25    MEDICAL     HCPCS        L8687
# 26    MEDICAL     HCPCS        L8688
# 27    MEDICAL       CPT        61860
# 28    MEDICAL       CPT        61863
# 29    MEDICAL       CPT        61864
# ..        ...       ...          ...
# 35    MEDICAL       CPT        63661
# 36    MEDICAL       CPT        63662
# 37    MEDICAL       CPT        63663
# 38    MEDICAL       CPT        63664
# 39    MEDICAL       CPT        64553
# 40    MEDICAL       CPT        64573
# 41    MEDICAL       CPT        64585
# 42    MEDICAL     HCPCS        C1778
# 43    MEDICAL     HCPCS        C1883
# 44    MEDICAL     HCPCS        L8680
# 45    MEDICAL       CPT        95970
# 46    MEDICAL       CPT        95971
# 47    MEDICAL       CPT        95972
# 48    MEDICAL       CPT        95974
# 49    MEDICAL       CPT        95978
# 50    MEDICAL       CPT        95979
# 51    MEDICAL       CPT        61888
# 52    MEDICAL       CPT        63688
# 53    MEDICAL       CPT        64570
# 54    MEDICAL       CPT        61534
# 55    MEDICAL       CPT        61536
# 56    MEDICAL       CPT        61537
# 57    MEDICAL       CPT        61538
# 58    MEDICAL       CPT        61539
# 59    MEDICAL       CPT        61540
# 60    MEDICAL       CPT        61541
# 61    MEDICAL       CPT        61543
# 62    MEDICAL       CPT        61566
# 63    MEDICAL       CPT        61567
# 64    MEDICAL       CPT        61850
#
#                                           description  \
# 0                            Narcolepsy w/o cataplexy
# 1                              Narcolepsy w/cataplexy
# 2        Narcolepsy in conditions classifed elsewhere
# 3   Narcolepsy w/cataplexy in conditions classifed...
# 4                            Narcolepsy and cataplexy
# 5                                          Narcolepsy
# 6                              Narcolepsy w/cataplexy
# 7                            Narcolepsy w/o cataplexy
# 8        Narcolepsy in conditions classifed elsewhere
# 9   Narcolepsy in conditions classifed elsewhere w...
# 10  Narcolepsy in conditions classifed elsewhere w...
# 11                                              Xyrem
# 12                                              Xyrem
# 13                                              Xyrem
# 14                                              Xyrem
# 15  Insertion or replacement of cranial neurostimu...
# 16  Insertion or replacement of cranial neurostimu...
# 17  Insertion or replacement of spinal neurostimul...
# 18  Incision for implantation of cranial nerve (e....
# 19  Revision or replacement of cranial nerve (e.g....
# 20                 Unlisted procedure, nervous system
# 21  Generator, neurostimulator (implantable), non-...
# 22  Generator, neurostimulator (implantable), with...
# 23  Implantable neurostimulator pulse generator, a...
# 24  Implantable neurostimulator pulse generator, s...
# 25  Implantable neurostimulator pulse generator, d...
# 26  Implantable neurostimulator pulse generator, d...
# 27  Craniectomy or craniotomy for implantation of ...
# 28  Twist drill, burr hole, craniotomy, or craniec...
# 29  Twist drill, burr hole, craniotomy, or craniec...
# ..                                                ...
# 35  Removal of spinal neurostimulator electrode pe...
# 36  Removal of spinal neurostimulator electrode pl...
# 37  Revision including replacement, when performed...
# 38  Revision including replacement, when performed...
# 39  Percutaneous implantation of neurostimulator e...
# 40  Incision for implantation of neurostimulator e...
# 41  Revision or removal of peripheral neurostimula...
# 42                Lead, neurostimulator (implantable)
# 43  Adaptor/extension, pacing lead or neurostimula...
# 44        Implantable neurostimulator electrode, each
# 45  Electronic analysis of implanted neurostimulat...
# 46  Electronic analysis of implanted neurostimulat...
# 47  Electronic analysis of implanted neurostimulat...
# 48  Electronic analysis of implanted neurostimulat...
# 49  Electronic analysis of implanted neurostimulat...
# 50  Electronic analysis of implanted neurostimulat...
# 51  Revision or removal of cranial neurostimulator...
# 52  Revision or removal of implanted spinal neuros...
# 53  Removal of cranial nerve (e.g., vagus nerve) n...
# 54  Craniotomy with elevation of bone flap; for ex...
# 55  Craniotomy with elevation of bone flap; for ex...
# 56  Craniotomy with elevation of bone flap; for lo...
# 57  Craniotomy with elevation of bone flap; for lo...
# 58  Craniotomy with elevation of bone flap; for lo...
# 59  Craniotomy with elevation of bone flap; for lo...
# 60  Craniotomy with elevation of bone flap; for tr...
# 61  Craniotomy with elevation of bone flap; for pa...
# 62  Craniotomy with elevation of bone flap; for se...
# 63  Craniotomy with elevation of bone flap; for mu...
# 64  Twist drill or burr hole(s) for implantation o...
#
#                                             source
# 0   DRG Treatment algorithms from Tamara Blutstein
# 1   DRG Treatment algorithms from Tamara Blutstein
# 2   DRG Treatment algorithms from Tamara Blutstein
# 3   DRG Treatment algorithms from Tamara Blutstein
# 4   DRG Treatment algorithms from Tamara Blutstein
# 5   DRG Treatment algorithms from Tamara Blutstein
# 6   DRG Treatment algorithms from Tamara Blutstein
# 7   DRG Treatment algorithms from Tamara Blutstein
# 8   DRG Treatment algorithms from Tamara Blutstein
# 9   DRG Treatment algorithms from Tamara Blutstein
# 10  DRG Treatment algorithms from Tamara Blutstein
# 11                                         redbook
# 12                                         redbook
# 13                                         redbook
# 14                                         redbook
# 15                                LivaNova project
# 16                                LivaNova project
# 17                                LivaNova project
# 18                                LivaNova project
# 19                                LivaNova project
# 20                                LivaNova project
# 21                                LivaNova project
# 22                                LivaNova project
# 23                                LivaNova project
# 24                                LivaNova project
# 25                                LivaNova project
# 26                                LivaNova project
# 27                                LivaNova project
# 28                                LivaNova project
# 29                                LivaNova project
# ..                                             ...
# 35                                LivaNova project
# 36                                LivaNova project
# 37                                LivaNova project
# 38                                LivaNova project
# 39                                LivaNova project
# 40                                LivaNova project
# 41                                LivaNova project
# 42                                LivaNova project
# 43                                LivaNova project
# 44                                LivaNova project
# 45                                LivaNova project
# 46                                LivaNova project
# 47                                LivaNova project
# 48                                LivaNova project
# 49                                LivaNova project
# 50                                LivaNova project
# 51                                LivaNova project
# 52                                LivaNova project
# 53                                LivaNova project
# 54                                LivaNova project
# 55                                LivaNova project
# 56                                LivaNova project
# 57                                LivaNova project
# 58                                LivaNova project
# 59                                LivaNova project
# 60                                LivaNova project
# 61                                LivaNova project
# 62                                LivaNova project
# 63                                LivaNova project
# 64                                LivaNova project
#
# [65 rows x 5 columns]

# %% [markdown]
# # Extract
# Extract raw data using the reference table and parameters for this module

# %% [markdown]
# ## Diagnosis
# Extract the subset from raven diagnosis
#
# **Parameters**
#   * `med_dx_start_dt`
#   * `med_dx_end_dt`
#
# **Input**
#   * `coh_basic_ref`
#   * `rwd_db.rwd.raven_external_claims_submits_diagnosis`
#
# **Output**
# * `coh_basic_raven_diagnosis`

# %%
# %%read_sql
#
# --CREATE TRANSIENT TABLE of all claims with the codes of interest
# DROP TABLE IF EXISTS coh_basic_raven_diagnosis;
# CREATE TRANSIENT TABLE coh_basic_raven_diagnosis as
#       SELECT dx.patient_id,
#              dx.claim_id,
#              dx.code_type,
#              dx.diagnosis,
#              dx.diagnosis_sequence,
#              dx.year_of_service
#         #FROM rwd_db.rwd.raven_claims_submits_diagnosis dx
#         FROM rwd_db.rwd.raven_external_claims_submits_diagnosis dx
#        WHERE year_of_service BETWEEN '{med_dx_start_dt}' AND '{med_dx_end_dt}'
#              AND diagnosis IN (SELECT code
#                                  FROM coh_basic_ref
#                                 WHERE data_asset = 'MEDICAL'
#                                       AND code_type IN ('ICD9','ICD10'));
# Out:
# Query started at 01:40:22 PM Eastern Daylight Time; Query executed in 0.03 mQuery started at 01:40:24 PM Eastern Daylight Time; Query executed in 0.23 m
#                                               status
# 0  Table COH_BASIC_RAVEN_DIAGNOSIS successfully c...

# %%
# %%read_sql
# --Check the raw counts of the initial data pull
# SELECT Count(*) AS row_cnt,
#        Count(Distinct patient_id) AS patient_cnt,
#        Count(Distinct claim_id) AS claim_cnt,
#        Count(Distinct diagnosis) AS diagnosis_cnt
#   FROM coh_basic_raven_diagnosis
# Out:
# Query started at 01:40:38 PM Eastern Daylight Time; Query executed in 0.20 m
#    row_cnt  patient_cnt  claim_cnt  diagnosis_cnt
# 0   188256        68205     181823              7

# %%
# %%read_sql
# --Review counts by year and code_type
# SELECT year(year_of_service) AS yr,
#        code_type,
#        Count(*) AS cnt
#   FROM coh_basic_raven_diagnosis
#  GROUP BY yr, code_type
#  ORDER BY yr, code_type
# Out:
# Query started at 01:40:50 PM Eastern Daylight Time; Query executed in 0.05 m
#      yr code_type     cnt
# 0  2017     ICD10  182605
# 1  2017      ICD9       4
# 2  2017      None    5647

# %%
# %%read_sql
# --Review the distribution of the diagnosis counts against the table
# SELECT ref.code_type,
#        ref.code,
#        ref.description,
#        Count(*) AS row_cnt,
#        Count(Distinct claim_id) AS claim_cnt,
#        Count(Distinct patient_id) AS patient_cnt
#   FROM coh_basic_ref ref
#        LEFT JOIN coh_basic_raven_diagnosis dx
#               ON ref.code = dx.diagnosis
#  WHERE ref.data_asset = 'MEDICAL'
#        AND ref.code_type IN ('ICD9','ICD10')
#  GROUP BY ref.code_type, ref.code, ref.description
#  ORDER BY Count(*) DESC
# Out:
# Query started at 01:40:53 PM Eastern Daylight Time; Query executed in 0.04 m
#    code_type    code                                        description  \
# 0      ICD10  G47419                           Narcolepsy w/o cataplexy
# 1      ICD10  G47411                             Narcolepsy w/cataplexy
# 2      ICD10   G4729  Narcolepsy in conditions classifed elsewhere w...
# 3      ICD10  G47421  Narcolepsy in conditions classifed elsewhere w...
# 4      ICD10   G4741                                         Narcolepsy
# 5      ICD10    G474                           Narcolepsy and cataplexy
# 6       ICD9   34700                           Narcolepsy w/o cataplexy
# 7       ICD9   34711  Narcolepsy w/cataplexy in conditions classifed...
# 8       ICD9    3471       Narcolepsy in conditions classifed elsewhere
# 9       ICD9   34701                             Narcolepsy w/cataplexy
# 10     ICD10   G4742       Narcolepsy in conditions classifed elsewhere
#
#     row_cnt  claim_cnt  patient_cnt
# 0    141572     137631        54603
# 1     42610      40957        15750
# 2      2392       2338         1286
# 3      1615       1585          666
# 4        60         59           36
# 5         4          4            3
# 6         3          3            3
# 7         1          0            0
# 8         1          0            0
# 9         1          0            0
# 10        1          0            0

# %% [markdown]
# ## Procedures
# Identify subset of Raven procedures that have the procedure or rx codes of interest between the dates.
#
# **Parameters**
#   * `med_proc_start_dt`
#   * `med_proc_end_dt`
#   * `med_rx_start_dt`
#   * `med_rx_end_dt`
#
# **Input**
#   * `coh_basic_ref`
#   * `rwd_db.rwd.raven_external_claims_submits_procedure`
#
# **Output**
# * `coh_basic_raven_procedure`

# %%
# %%read_sql
# --Identify subset of procedure claims of interest for procedure & rx codes of interest
# DROP TABLE IF EXISTS coh_basic_raven_procedure;
# CREATE TRANSIENT TABLE coh_basic_raven_procedure as
#       SELECT patient_id,
#              claim_id,
#              procedure_type,
#              procedure,
#              year_of_service,
#              ndc
#         #FROM rwd_db.rwd.raven_claims_submits_procedure
#         FROM rwd_db.rwd.raven_external_claims_submits_procedure
#        WHERE year_of_service BETWEEN '{med_proc_start_dt}' AND '{med_proc_end_dt}'
#              AND (procedure IN (SELECT code
#                                  FROM coh_basic_ref
#                                 WHERE data_asset='MEDICAL'
#                                       AND code_type IN ('CPT','JCODE','HCPCS','ICD10PROC'))
#                  OR ndc IN (SELECT code
#                               FROM coh_basic_ref
#                              WHERE data_asset='MEDICAL'
#                                    AND code_type='NDC'));
# Out:
# Query started at 01:40:55 PM Eastern Daylight Time; Query executed in 0.04 mQuery started at 01:40:58 PM Eastern Daylight Time; Query executed in 1.62 m
#                                               status
# 0  Table COH_BASIC_RAVEN_PROCEDURE successfully c...

# %%
# %%read_sql
# --Check the raw counts from the procedure data pull
# SELECT Count(*)                     AS row_cnt,
#        Count(DISTINCT patient_id)   AS patient_cnt,
#        Count(DISTINCT claim_id) AS claim_cnt,
#        Count(DISTINCT procedure)    AS procedure_cnt,
#        Count(DISTINCT ndc)          AS ndc_cnt
#   FROM coh_basic_raven_procedure;
# Out:
# Query started at 01:42:35 PM Eastern Daylight Time; Query executed in 0.13 m
#    row_cnt  patient_cnt  claim_cnt  procedure_cnt  ndc_cnt
# 0   444586       108389     281726             50       70

# %%
# %%read_sql
# --Review the distribution of the diagnosis counts against the table
# SELECT ref.code_type,
#        ref.code,
#        ref.description,
#        Count(*) AS row_cnt,
#        Count(Distinct claim_id) AS claim_cnt,
#        Count(Distinct patient_id) AS patient_cnt
#   FROM coh_basic_ref ref
#        LEFT JOIN coh_basic_raven_procedure proc
#               ON ref.code = proc.procedure
#  WHERE ref.data_asset = 'MEDICAL'
#        AND ref.code_type IN ('CPT','JCODE','HCPCS','ICD10PROC')
#  GROUP BY ref.code_type, ref.code, ref.description
#  ORDER BY Count(*) DESC;
# Out:
# Query started at 01:42:43 PM Eastern Daylight Time; Query executed in 0.06 m
#    code_type   code                                        description  \
# 0        CPT  63650  Percutaneous implantation of neurostimulator e...
# 1        CPT  95972  Electronic analysis of implanted neurostimulat...
# 2        CPT  63685  Insertion or replacement of spinal neurostimul...
# 3        CPT  95970  Electronic analysis of implanted neurostimulat...
# 4      HCPCS  C1778                Lead, neurostimulator (implantable)
# 5        CPT  95978  Electronic analysis of implanted neurostimulat...
# 6        CPT  64999                 Unlisted procedure, nervous system
# 7        CPT  95971  Electronic analysis of implanted neurostimulat...
# 8        CPT  95974  Electronic analysis of implanted neurostimulat...
# 9      HCPCS  C1767  Generator, neurostimulator (implantable), non-...
# 10       CPT  63655  Laminectomy for implantation of neurostimulato...
# 11       CPT  63688  Revision or removal of implanted spinal neuros...
# 12     HCPCS  C1820  Generator, neurostimulator (implantable), with...
# 13       CPT  61885  Insertion or replacement of cranial neurostimu...
# 14       CPT  64585  Revision or removal of peripheral neurostimula...
# 15     HCPCS  C1883  Adaptor/extension, pacing lead or neurostimula...
# 16       CPT  63661  Removal of spinal neurostimulator electrode pe...
# 17     HCPCS  L8680        Implantable neurostimulator electrode, each
# 18       CPT  61886  Insertion or replacement of cranial neurostimu...
# 19       CPT  64568  Incision for implantation of cranial nerve (e....
# 20       CPT  63662  Removal of spinal neurostimulator electrode pl...
# 21     HCPCS  L8679  Implantable neurostimulator pulse generator, a...
# 22       CPT  63663  Revision including replacement, when performed...
# 23       CPT  95979  Electronic analysis of implanted neurostimulat...
# 24       CPT  61867  Twist drill, burr hole, craniotomy, or craniec...
# 25       CPT  63664  Revision including replacement, when performed...
# 26       CPT  64553  Percutaneous implantation of neurostimulator e...
# 27       CPT  61888  Revision or removal of cranial neurostimulator...
# 28       CPT  61868  Twist drill, burr hole, craniotomy, or craniec...
# 29       CPT  61880  Revision or removal of intracranial neurostimu...
# 30       CPT  61863  Twist drill, burr hole, craniotomy, or craniec...
# 31       CPT  64569  Revision or replacement of cranial nerve (e.g....
# 32     HCPCS  L8687  Implantable neurostimulator pulse generator, d...
# 33     HCPCS  L8686  Implantable neurostimulator pulse generator, s...
# 34       CPT  61537  Craniotomy with elevation of bone flap; for lo...
# 35       CPT  61864  Twist drill, burr hole, craniotomy, or craniec...
# 36       CPT  64570  Removal of cranial nerve (e.g., vagus nerve) n...
# 37       CPT  61536  Craniotomy with elevation of bone flap; for ex...
# 38     HCPCS  L8688  Implantable neurostimulator pulse generator, d...
# 39       CPT  61538  Craniotomy with elevation of bone flap; for lo...
# 40       CPT  61860  Craniectomy or craniotomy for implantation of ...
# 41       CPT  61543  Craniotomy with elevation of bone flap; for pa...
# 42       CPT  61534  Craniotomy with elevation of bone flap; for ex...
# 43       CPT  61540  Craniotomy with elevation of bone flap; for lo...
# 44       CPT  61566  Craniotomy with elevation of bone flap; for se...
# 45       CPT  61541  Craniotomy with elevation of bone flap; for tr...
# 46       CPT  61539  Craniotomy with elevation of bone flap; for lo...
# 47       CPT  61850  Twist drill or burr hole(s) for implantation o...
# 48       CPT  61567  Craniotomy with elevation of bone flap; for mu...
# 49       CPT  64573  Incision for implantation of neurostimulator e...
#
#     row_cnt  claim_cnt  patient_cnt
# 0     81208      55651        27082
# 1     48374      47983        24781
# 2     44056      43011        24146
# 3     35665      35064        16284
# 4     27233      25869        17214
# 5     24703      24399         8332
# 6     22290      21109        12011
# 7     21135      20885        10962
# 8     20413      20153         7048
# 9     19376      18712        13626
# 10    16541      16069         8482
# 11    11181      10916         6791
# 12    10571       9993         7333
# 13     8340       8018         4690
# 14     6579       6339         3936
# 15     6217       5952         3840
# 16     6068       5734         3659
# 17     4681       3960         2643
# 18     4334       4230         2610
# 19     3682       3576         1985
# 20     3595       3482         1965
# 21     3040       2760         1104
# 22     2784       2553         1553
# 23     2739       2678         1394
# 24     1649       1632          967
# 25     1532       1483          822
# 26     1148       1084          604
# 27      955        923          639
# 28      552        547          370
# 29      549        523          293
# 30      536        526          322
# 31      442        434          257
# 32      405        397          309
# 33      335        316          206
# 34      302        301          220
# 35      288        274          170
# 36      286        279          171
# 37      150        146           95
# 38      104        104           86
# 39       93         93           65
# 40       75         72           47
# 41       74         74           45
# 42       68         68           59
# 43       64         62           47
# 44       53         53           37
# 45       49         49           38
# 46       36         36           23
# 47       28         27           16
# 48        6          6            4
# 49        1          0            0

# %% [markdown]
# ## Pharmacy
# Identify patients from Raven Pharmacy using the codes of interest
#
# **Parameters**
# * `phar_rx_start_dt`
# * `phar_rx_end_dt`
#
# **Input**
#   * `coh_basic_ref`
#   **External table**
#   * `rwd_db.rwd.raven_external_pharmacy `
#
# **Output**
# * `coh_basic_raven_pharmacy`

# %%
# %%read_sql
# --Create pharmacy table with codes of interest
# DROP TABLE IF EXISTS coh_basic_raven_pharmacy;
# CREATE TRANSIENT TABLE coh_basic_raven_pharmacy AS
#     SELECT patient_id,
#            claim_id,
#            prescriber_id            AS npi,
#            product_or_service_id    AS ndc,
#            date_of_service
#      # FROM rwd_db.rwd.raven_pharmacy
#      FROM rwd_db.rwd.raven_external_pharmacy
#      WHERE date_of_service BETWEEN '{phar_rx_start_dt}' AND '{phar_rx_end_dt}'
#            AND product_or_service_id IN (SELECT code
#                                            FROM coh_basic_ref
#                                           WHERE data_asset='PHARMACY'
#                                                 AND code_type='NDC');
# Out:
# Query started at 01:42:47 PM Eastern Daylight Time; Query executed in 0.03 mQuery started at 01:42:49 PM Eastern Daylight Time; Query executed in 0.32 m
#                                               status
# 0  Table COH_BASIC_RAVEN_PHARMACY successfully cr...

# %%
# %%read_sql
# SELECT Count(*) AS row_cnt,
#        Count(Distinct claim_id) AS claim_cnt,
#        Count(Distinct patient_id) AS patient_cnt,
#        Count(Distinct ndc) AS ndc_cnt
#   FROM coh_basic_raven_pharmacy
# Out:
# Query started at 01:43:08 PM Eastern Daylight Time; Query executed in 0.04 m
#    row_cnt  claim_cnt  patient_cnt  ndc_cnt
# 0      511        510          137        1

# %%
# %%read_sql
# SELECT ndc,
#        Count(*) AS row_cnt,
#        Count(Distinct claim_id) AS claim_cnt,
#        Count(Distinct patient_id) AS patient_cnt,
#        Count(Distinct ndc) AS ndc_cnt
#   FROM coh_basic_raven_pharmacy
#  GROUP BY ndc
#  ORDER BY row_cnt DESC;
# Out:
# Query started at 01:43:11 PM Eastern Daylight Time; Query executed in 0.04 m
#            ndc  row_cnt  claim_cnt  patient_cnt  ndc_cnt
# 0  68727010001      511        510          137        1

# %% [markdown]
# # Create cohorts
# Create a few key tables for the cohorts

# %% [markdown]
# ## Patients
# Create a cohort of all the unique patient_ids
#
# **Input**
# * `coh_basic_raven_diagnosis`
# * `coh_basic_raven_procedure`
# * `coh_basic_raven_pharmacy`
#
# **Output**
# * `coh_pt`

# %%
# %%read_sql
# --Create final cohort of unique patients from the extracts
# DROP TABLE IF EXISTS coh_pt;
# CREATE TRANSIENT TABLE coh_pt AS
#   SELECT patient_id,
#          Max(src_med_dx)   AS src_med_dx,
#          Max(src_med_proc) AS src_med_proc,
#          Max(src_med_rx)   AS src_med_rx,
#          Max(src_phar_rx)  AS src_phar_rx
#     FROM (--Medical Diagnosis Claims
#           SELECT patient_id,
#                  1 AS src_med_dx,
#                  0 AS src_med_proc,
#                  0 AS src_med_rx,
#                  0 AS src_phar_rx
#             FROM coh_basic_raven_diagnosis
#           UNION
#           --Medical Procedural claims using procedure codes
#           SELECT patient_id,
#                  0 AS src_med_dx,
#                  1 AS src_med_proc,
#                  0 AS src_med_rx,
#                  0 AS src_phar_rx
#             FROM coh_basic_raven_procedure
#            WHERE procedure IN (SELECT code
#                                  FROM coh_basic_ref
#                                 WHERE data_asset='MEDICAL'
#                                       AND code_type IN ('CPT','JCODE','HCPCS','ICD10PROC'))
#           UNION
#           --Medical Procedural claims using ndc codes
#           SELECT patient_id,
#                  0 AS src_med_dx,
#                  0 AS src_med_proc,
#                  1 AS src_med_rx,
#                  0 AS src_phar_rx
#             FROM coh_basic_raven_procedure
#            WHERE ndc IN (SELECT code
#                            FROM coh_basic_ref
#                           WHERE data_asset='MEDICAL'
#                                AND code_type='NDC')
#           UNION
#          --Pharmacy claims
#           SELECT patient_id,
#                  0 AS src_med_dx,
#                  0 AS src_med_proc,
#                  0 AS src_med_rx,
#                  1 AS src_phar_rx
#             FROM coh_basic_raven_pharmacy)
#    WHERE patient_id IS NOT NULL
#    GROUP BY patient_id;
# Out:
# Query started at 01:43:13 PM Eastern Daylight Time; Query executed in 0.03 mQuery started at 01:43:14 PM Eastern Daylight Time; Query executed in 0.11 m
#                                status
# 0  Table COH_PT successfully created.

# %%
# %%read_sql
# --Review counts and confirm they are unique
# SELECT Count(*)                   AS row_cnt,
#        Count(DISTINCT patient_id) AS patient_cnt,
#        Sum(src_med_dx)            AS src_med_dx_sum,
#        Sum(src_med_proc)          AS src_med_proc_sum,
#        Sum(src_med_rx)            AS src_med_rx_sum,
#        Sum(src_phar_rx)           AS src_phar_rx_sum
#   FROM coh_pt
# Out:
# Query started at 01:43:21 PM Eastern Daylight Time; Query executed in 0.11 m
#    row_cnt  patient_cnt  src_med_dx_sum  src_med_proc_sum  src_med_rx_sum  \
# 0   176421       176421           68205            108388               1
#
#    src_phar_rx_sum
# 0              137

# %% [markdown]
# ## Claims
# Identify all of the unique claim numbers that were extracted from the analysis for later use
#
# **Input**
# * `coh_basic_raven_diagnosis`
# * `coh_basic_raven_procedure`
# * `coh_basic_raven_pharmacy`
#
# **Output**
# * `coh_claims`

# %%
# %%read_sql
# --Create final cohort of unique patients from the extracts
# DROP TABLE IF EXISTS coh_claim;
# CREATE TRANSIENT TABLE coh_claim AS
#   SELECT patient_id,
#          claim_id,
#          Max(src_med_dx)   AS src_med_dx,
#          Max(src_med_proc) AS src_med_proc,
#          Max(src_med_rx)   AS src_med_rx,
#          Max(src_phar_rx)  AS src_phar_rx
#     FROM (--Medical Diagnosis Claims
#           SELECT patient_id,
#                  claim_id,
#                  1 AS src_med_dx,
#                  0 AS src_med_proc,
#                  0 AS src_med_rx,
#                  0 AS src_phar_rx
#             FROM coh_basic_raven_diagnosis
#           UNION
#           --Medical Procedural claims using procedure codes
#           SELECT patient_id,
#                  claim_id,
#                  0 AS src_med_dx,
#                  1 AS src_med_proc,
#                  0 AS src_med_rx,
#                  0 AS src_phar_rx
#             FROM coh_basic_raven_procedure
#            WHERE procedure IN (SELECT code
#                                  FROM coh_basic_ref
#                                 WHERE data_asset='MEDICAL'
#                                       AND code_type IN ('CPT','JCODE','HCPCS','ICD10PROC'))
#           UNION
#           --Medical Procedural claims using ndc codes
#           SELECT patient_id,
#                  claim_id,
#                  0 AS src_med_dx,
#                  0 AS src_med_proc,
#                  1 AS src_med_rx,
#                  0 AS src_phar_rx
#             FROM coh_basic_raven_procedure
#            WHERE ndc IN (SELECT code
#                            FROM coh_basic_ref
#                           WHERE data_asset='MEDICAL'
#                                AND code_type='NDC')
#           UNION
#          --Pharmacy claims
#           SELECT patient_id,
#                  claim_id,
#                  0 AS src_med_dx,
#                  0 AS src_med_proc,
#                  0 AS src_med_rx,
#                  1 AS src_phar_rx
#             FROM coh_basic_raven_pharmacy)
#    WHERE patient_id IS NOT NULL
#          AND claim_id IS NOT NULL
#    GROUP BY patient_id, claim_id;
# Out:
# Query started at 01:43:27 PM Eastern Daylight Time; Query executed in 0.03 mQuery started at 01:43:29 PM Eastern Daylight Time; Query executed in 0.12 m
#                                   status
# 0  Table COH_CLAIM successfully created.

# %%
# %%read_sql
# --Review counts and confirm they are unique
# SELECT Count(*)                     AS row_cnt,
#        Count(DISTINCT patient_id)   AS patient_cnt,
#        Count(Distinct claim_id) AS claim_cnt,
#        Sum(src_med_dx)              AS src_med_dx_sum,
#        Sum(src_med_proc)            AS src_med_proc_sum,
#        Sum(src_med_rx)              AS src_med_rx_sum,
#        Sum(src_phar_rx)             AS src_phar_rx_sum
#   FROM coh_claim
# Out:
# Query started at 01:43:36 PM Eastern Daylight Time; Query executed in 0.11 m
#    row_cnt  patient_cnt  claim_cnt  src_med_dx_sum  src_med_proc_sum  \
# 0   458082       176421     458082          180213            277567
#
#    src_med_rx_sum  src_phar_rx_sum
# 0               1              387
