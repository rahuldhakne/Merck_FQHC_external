# %% [markdown]
# # Comorbidities
# Tidy tables of the patient's custom comorbidities identified from medical claims between two dates.  All table start with `cld_comorbid`
#
# **Script**
# * [scripts/cld/comorbidities.ipynb](./scripts/cld/comorbidities.ipynb)
#
# **Prior Script(s)**
# * [scripts/extract/raven_diagnosis.ipynb](./scripts/extract/raven_diagnosis.ipynb)
#
# **Parameters**
# * `in/cld/comorbid_custom.xlsx[param]`
#
# **Input**
# * `coh_pt`
# * `de_raven_diagnosis`
# * `cld_comorbid_ref`: `in/cld/comorbid_custom.xlsx[ref]`
#
# **Output**
# * `cld_comorbid`
# * `cld_comorbid_pivot` (TBD)
#
# **Review**
# * [scripts/cld/comorbidities.html](./scripts/cld/comorbidities.html)

# %%
#Import libraries for this notebook
import pandas as pd  
from drg_connect import Snowflake
import numpy as np
import pickle
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

#Load connection variables to connect_dict
with open('../../out/conn/connect_dict.pickle', 'rb') as handle:
    connect_dict = pickle.load(handle)

#Create Eegine to connect to snowflake
snow = Snowflake(role=connect_dict['role'],
                 warehouse=connect_dict['warehouse'],
                 database=connect_dict['database'],
                 schema=connect_dict['schema'])

#Finish engine setup
engine = snow.engine
# %load_ext sql_magic
# %config SQL.conn_name = 'engine'  #Set the sql_magic connection engine
# %config SQL.output_result = True  #Enable output to std out
# %config SQL.notify_result = False #disable browser notifications
# Out:
# The sql_magic extension is already loaded. To reload it, use:
#   %reload_ext sql_magic

# %% [markdown]
# # Reference
# Upload reference table used to identify the custom comorbidities
#
# **Input**
#   * `in/cld/comorbidities.xlsx[ref]`
#
# **Output**
# * `coh_basic_ref`

# %%
#Upload reference table from excel to snowflake and review snowflake output
df = pd.read_excel('../../in/cld/comorbidities.xlsx', sheet_name='ref', skiprows=4, dtype=str)

#Strip white space and make referrable columns uppercase
df = df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
df[['code_type','code']] =  \
    df[['code_type','code']].apply(lambda x: x.str.upper() if x.dtype == "object" else x)
df.code= df.code.str.replace(r'\W+','').astype('str')

#Upload to snowflake
snow.drop_table("cld_comorbid_ref")
snow.upload_dataframe(df,"cld_comorbid_ref")
snow.select("SELECT * FROM cld_comorbid_ref")
# Out:
# DROP TABLE IF EXISTS ref_db.semi_custom.cld_comorbid_ref;
# Initiating login request with your identity provider. A browser window should have opened for you to complete the login. If you can't see it, check existing browser windows, or your OS settings. Press CTRL+C to abort and try again...
# Table ref_db.semi_custom.cld_comorbid_ref dropped! (╯°□°）╯︵ ┻━┻
# Upload into ref_db.semi_custom.cld_comorbid_ref successful! ┬──┬◡ﾉ(°-°ﾉ)
#                 cat1                              cat2 code_type    code  \
# 0    sleep disorders                        narcolepsy      ICD9   34700
# 1    sleep disorders                        narcolepsy      ICD9   34701
# 2    sleep disorders                        narcolepsy      ICD9    3471
# 3    sleep disorders                        narcolepsy      ICD9   34711
# 4    sleep disorders                        narcolepsy     ICD10    G474
# 5    sleep disorders                        narcolepsy     ICD10   G4741
# 6    sleep disorders                        narcolepsy     ICD10  G47411
# 7    sleep disorders                        narcolepsy     ICD10  G47419
# 8    sleep disorders                        narcolepsy     ICD10   G4742
# 9    sleep disorders                        narcolepsy     ICD10  G47421
# 10   sleep disorders                        narcolepsy     ICD10   G4729
# 11   sleep disorders                        parasomnia     ICD10    G475
# 12   sleep disorders                        parasomnia     ICD10   G4750
# 13   sleep disorders                        parasomnia     ICD10   G4751
# 14   sleep disorders                        parasomnia     ICD10   G4752
# 15   sleep disorders                        parasomnia     ICD10   G4753
# 16   sleep disorders                        parasomnia     ICD10   G4754
# 17   sleep disorders                        parasomnia     ICD10   G4759
# 18   sleep disorders                        parasomnia      ICD9    3247
# 19   sleep disorders                        parasomnia      ICD9   32740
# 20   sleep disorders                        parasomnia      ICD9   32741
# 21   sleep disorders                        parasomnia      ICD9   32742
# 22   sleep disorders                        parasomnia      ICD9   32743
# 23   sleep disorders                        parasomnia      ICD9   32744
# 24   sleep disorders                        parasomnia      ICD9   32749
# 25       psychiatric                 suicidal ideation      ICD9   V6284
# 26       psychiatric                 suicidal ideation     ICD10  R45851
# 27       psychiatric                        depression      ICD9    2962
# 28       psychiatric                        depression      ICD9   29621
# 29       psychiatric                        depression      ICD9   29622
# ..               ...                               ...       ...     ...
# 113  sleep disorders  circadian rhythm sleep disorders     ICD10   G4724
# 114  sleep disorders  circadian rhythm sleep disorders     ICD10   G4726
# 115  sleep disorders                       parasomnias     ICD10    F513
# 116  sleep disorders                       parasomnias     ICD10    F514
# 117  sleep disorders                       parasomnias     ICD10    F515
# 118  sleep disorders                       parasomnias     ICD10    F518
# 119  sleep disorders                       parasomnias     ICD10   G4751
# 120  sleep disorders                       parasomnias     ICD10   G4752
# 121  sleep disorders                       parasomnias     ICD10   G4753
# 122  sleep disorders                       parasomnias     ICD10   G4759
# 123  sleep disorders  sleep related movement disorders     ICD10   G2581
# 124  sleep disorders   periodic limb movement disorder     ICD10   G4761
# 125  sleep disorders   periodic limb movement disorder     ICD10   G4762
# 126  sleep disorders   periodic limb movement disorder     ICD10   G4763
# 127  sleep disorders      drug induced sleep disorders     ICD10  F11182
# 128  sleep disorders      drug induced sleep disorders     ICD10  F11282
# 129  sleep disorders      drug induced sleep disorders     ICD10  F11982
# 130  sleep disorders      drug induced sleep disorders     ICD10  F13182
# 131  sleep disorders      drug induced sleep disorders     ICD10  F13282
# 132  sleep disorders      drug induced sleep disorders     ICD10  F13982
# 133  sleep disorders      drug induced sleep disorders     ICD10  F14182
# 134  sleep disorders      drug induced sleep disorders     ICD10  F14282
# 135  sleep disorders      drug induced sleep disorders     ICD10  F14982
# 136  sleep disorders      drug induced sleep disorders     ICD10  F15182
# 137  sleep disorders      drug induced sleep disorders     ICD10  F15282
# 138  sleep disorders      drug induced sleep disorders     ICD10  F15982
# 139  sleep disorders      drug induced sleep disorders     ICD10  F19182
# 140  sleep disorders      drug induced sleep disorders     ICD10   F1921
# 141  sleep disorders      drug induced sleep disorders     ICD10  F19282
# 142  sleep disorders      drug induced sleep disorders     ICD10  F19982
#
#                                            description  \
# 0                             Narcolepsy w/o cataplexy
# 1                               Narcolepsy w/cataplexy
# 2         Narcolepsy in conditions classifed elsewhere
# 3    Narcolepsy w/cataplexy in conditions classifed...
# 4                             Narcolepsy and cataplexy
# 5                                           Narcolepsy
# 6                               Narcolepsy w/cataplexy
# 7                             Narcolepsy w/o cataplexy
# 8         Narcolepsy in conditions classifed elsewhere
# 9    Narcolepsy in conditions classifed elsewhere w...
# 10   Narcolepsy in conditions classifed elsewhere w...
# 11                                          Parasomnia
# 12                              Parasomnia unspecified
# 13                     Parasomnia Confusional arousals
# 14              Parasomnia REM sleep behavior disorder
# 15       Parasomnia Recurrent isolated sleep paralysis
# 16       Parasomnia in conditions classified elsewhere
# 17                         Parasomnia Other parasomnia
# 18                                  Organic parasomnia
# 19              Organic parasomnia: Organic parasomnia
# 20            Organic parasomnia: Confusional arousals
# 21     Organic parasomnia: REM sleep behavior disorder
# 22   Organic parasomnia: Recurrent isolated sleep p...
# 23   Organic parasomnia: Parasomnia in conditions c...
# 24        Organic parasomnia: Other organic parasomnia
# 25                                   Suicidal thoughts
# 26                                   Suicidal ideation
# 27   Major Depressive Affective Disorder Single Epi...
# 28   Major Depressive Affective Disorder Single Epi...
# 29   Major Depressive Affective Disorder Single Epi...
# ..                                                 ...
# 113                                  Free-Running Type
# 114              Shift Work Type (Shift Work Disorder)
# 115                                       Sleepwalking
# 116                                      Night Terrors
# 117                                 Nightmare Disorder
# 118  Other sleep disorders not due to a substance o...
# 119                               Confusional Arousals
# 120                        REM Sleep Behavior Disorder
# 121                 Recurrent Isolated Sleep Paralysis
# 122                                   Other parasomnia
# 123                        Restless Legs Syndrome  RLS
# 124                    Periodic Limb Movement Disorder
# 125                           Sleep Related Leg Cramps
# 126                              Sleep Related Bruxism
# 127    Opioid abuse with opioid-induced sleep disorder
# 128  Opioid dependence with opioid-induced sleep di...
# 129                                         Opioid use
# 130                                           Sedative
# 131                                           Sedative
# 132                                           Sedative
# 133  Cocaine abuse with cocaine-induced sleep disorder
# 134  Cocaine dependence with cocaine-induced sleep ...
# 135                                        Cocaine use
# 136  Other stimulant abuse with stimulant-induced s...
# 137  Other stimulant dependence with stimulant-indu...
# 138                                Other stimulant use
# 139  Other psychoactive substance abuse with psycho...
# 140            Other psychoactive substance dependence
# 141  Other psychoactive substance dependence with p...
# 142                   Other psychoactive substance use
#
#                                                 source
# 0       DRG Treatment algorithms from Tamara Blutstein
# 1       DRG Treatment algorithms from Tamara Blutstein
# 2       DRG Treatment algorithms from Tamara Blutstein
# 3       DRG Treatment algorithms from Tamara Blutstein
# 4       DRG Treatment algorithms from Tamara Blutstein
# 5       DRG Treatment algorithms from Tamara Blutstein
# 6       DRG Treatment algorithms from Tamara Blutstein
# 7       DRG Treatment algorithms from Tamara Blutstein
# 8       DRG Treatment algorithms from Tamara Blutstein
# 9       DRG Treatment algorithms from Tamara Blutstein
# 10      DRG Treatment algorithms from Tamara Blutstein
# 11   http://www.icd10data.com/ICD10CM/Codes/G00-G99...
# 12   http://www.icd10data.com/ICD10CM/Codes/G00-G99...
# 13   http://www.icd10data.com/ICD10CM/Codes/G00-G99...
# 14   http://www.icd10data.com/ICD10CM/Codes/G00-G99...
# 15   http://www.icd10data.com/ICD10CM/Codes/G00-G99...
# 16   http://www.icd10data.com/ICD10CM/Codes/G00-G99...
# 17   http://www.icd10data.com/ICD10CM/Codes/G00-G99...
# 18   http://www.icd9data.com/2014/Volume1/320-389/3...
# 19                                                 nan
# 20   http://www.icd9data.com/2014/Volume1/320-389/3...
# 21   http://www.icd9data.com/2014/Volume1/320-389/3...
# 22   http://www.icd9data.com/2014/Volume1/320-389/3...
# 23   http://www.icd9data.com/2014/Volume1/320-389/3...
# 24   http://www.icd9data.com/2014/Volume1/320-389/3...
# 25   http://www.icd9data.com/2015/Volume1/V01-V91/V...
# 26   http://www.icd10data.com/ICD10CM/Codes/R00-R99...
# 27      DRG Treatment algorithms from Tamara Blutstein
# 28      DRG Treatment algorithms from Tamara Blutstein
# 29      DRG Treatment algorithms from Tamara Blutstein
# ..                                                 ...
# 113  https://www.sleepassociation.org/sleep-disorde...
# 114  https://www.sleepassociation.org/sleep-disorde...
# 115  https://www.sleepassociation.org/sleep-disorde...
# 116  https://www.sleepassociation.org/sleep-disorde...
# 117  https://www.sleepassociation.org/sleep-disorde...
# 118  https://www.sleepassociation.org/sleep-disorde...
# 119  https://www.sleepassociation.org/sleep-disorde...
# 120  https://www.sleepassociation.org/sleep-disorde...
# 121  https://www.sleepassociation.org/sleep-disorde...
# 122  https://www.sleepassociation.org/sleep-disorde...
# 123  https://www.sleepassociation.org/sleep-disorde...
# 124  https://www.sleepassociation.org/sleep-disorde...
# 125  https://www.sleepassociation.org/sleep-disorde...
# 126  https://www.sleepassociation.org/sleep-disorde...
# 127  https://www.sleepassociation.org/sleep-disorde...
# 128  https://www.sleepassociation.org/sleep-disorde...
# 129                                                nan
# 130                                                nan
# 131                                                nan
# 132                                                nan
# 133  https://www.sleepassociation.org/sleep-disorde...
# 134  https://www.sleepassociation.org/sleep-disorde...
# 135                                                nan
# 136  https://www.sleepassociation.org/sleep-disorde...
# 137  https://www.sleepassociation.org/sleep-disorde...
# 138                                                nan
# 139  https://www.sleepassociation.org/sleep-disorde...
# 140                                                nan
# 141  https://www.sleepassociation.org/sleep-disorde...
# 142                                                nan
#
# [143 rows x 6 columns]

# %% [markdown]
# # Comorbidities
# Identify the patients comorbidities based on the parameters and inputs
#
# **Parameters**
#   * NONE
#
# **Input**
#   * `coh_pt`
#   * `de_raven_diagnosis`
#   * `cld_comorbid_ref
#
# **Output**
# * `cld_comorbid`

# %%
# %%read_sql
# --Create raven diagnosis table
# DROP TABLE IF EXISTS cld_comorbid;
# CREATE TRANSIENT TABLE cld_comorbid AS
#       SELECT coh.patient_id,
#              dx.claim_id,
#              dx.year_of_service,
#              ref.cat1,
#              ref.cat2
#         FROM coh_pt coh
#              JOIN de_raven_diagnosis dx
#                ON coh.patient_id = dx.patient_id
#              JOIN cld_comorbid_ref ref
#                ON ref.code = dx.diagnosis
#        GROUP BY coh.patient_id, dx.claim_id, dx.year_of_service, ref.cat1, ref.cat2
# Out:
# Query started at 03:07:34 PM Eastern Daylight Time; Query executed in 0.04 mQuery started at 03:07:36 PM Eastern Daylight Time; Query executed in 0.09 m
#                                      status
# 0  Table CLD_COMORBID successfully created.

# %%
# %%read_sql
# --Review counts as a sanity check
# SELECT Count(*) AS row_cnt,
#        Count(Distinct patient_id) AS pt_cnt,
#        Count(Distinct cat1) AS cat1_cnt,
#        Count(Distinct cat2) AS cat2_cnt
#   FROM cld_comorbid;
# Out:
# Query started at 03:07:41 PM Eastern Daylight Time; Query executed in 0.10 m
#    row_cnt  pt_cnt  cat1_cnt  cat2_cnt
# 0  2257808  133285         2        13

# %%
# %%read_sql
# --Quick distribution of the counts
# SELECT cat1,
#        cat2,
#        Count(Distinct patient_id) AS pt_cnt,
#        Count(Distinct patient_id) / (SELECT Count(*)
#                                       FROM coh_pt) AS pct
#   FROM cld_comorbid
#  GROUP BY cat1, cat2
#  ORDER BY pt_cnt desc;
# Out:
# Query started at 03:07:47 PM Eastern Daylight Time; Query executed in 0.03 m
#                cat1                               cat2  pt_cnt       pct
# 0   sleep disorders                         narcolepsy   68409  0.387773
# 1   sleep disorders                        hypersomnia   67046  0.380047
# 2   sleep disorders  sleep related breathing disorders   63861  0.361993
# 3       psychiatric                         depression   62453  0.354012
# 4       psychiatric                            anxiety   55934  0.317059
# 5   sleep disorders                           insomnia   35709  0.202415
# 6   sleep disorders   sleep related movement disorders   11147  0.063186
# 7   sleep disorders    periodic limb movement disorder    5197  0.029459
# 8   sleep disorders                        parasomnias    3575  0.020265
# 9       psychiatric                  suicidal ideation    3443  0.019516
# 10  sleep disorders                         parasomnia    3422  0.019397
# 11  sleep disorders   circadian rhythm sleep disorders    1805  0.010232
# 12  sleep disorders       drug induced sleep disorders     357  0.002024

# %%
# %%read_sql
# --Quick distribution of the counts
# SELECT cat1,
#        cat2,
#        Count(Distinct patient_id) AS pt_cnt,
#        Count(Distinct patient_id) / (SELECT Count(*)
#                                       FROM coh_pt) AS pct
#   FROM cld_comorbid
#  GROUP BY cat1, cat2
#  ORDER BY pt_cnt desc;
# Out:
# Query started at 03:07:50 PM Eastern Daylight Time; Query executed in 0.03 m
#                cat1                               cat2  pt_cnt       pct
# 0   sleep disorders                         narcolepsy   68409  0.387773
# 1   sleep disorders                        hypersomnia   67046  0.380047
# 2   sleep disorders  sleep related breathing disorders   63861  0.361993
# 3       psychiatric                         depression   62453  0.354012
# 4       psychiatric                            anxiety   55934  0.317059
# 5   sleep disorders                           insomnia   35709  0.202415
# 6   sleep disorders   sleep related movement disorders   11147  0.063186
# 7   sleep disorders    periodic limb movement disorder    5197  0.029459
# 8   sleep disorders                        parasomnias    3575  0.020265
# 9       psychiatric                  suicidal ideation    3443  0.019516
# 10  sleep disorders                         parasomnia    3422  0.019397
# 11  sleep disorders   circadian rhythm sleep disorders    1805  0.010232
# 12  sleep disorders       drug induced sleep disorders     357  0.002024

# %%
# %%read_sql
# --Quick distribution of the counts
# SELECT cat1,
#        Count(Distinct patient_id) AS pt_cnt,
#        Count(Distinct patient_id) / (SELECT Count(*)
#                                       FROM coh_pt) AS pct
#   FROM cld_comorbid
#  GROUP BY cat1
#  ORDER BY pt_cnt desc;
# Out:
# Query started at 03:07:51 PM Eastern Daylight Time; Query executed in 0.04 m
#               cat1  pt_cnt       pct
# 0  sleep disorders  107969  0.612017
# 1      psychiatric   81457  0.461735
